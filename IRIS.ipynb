# %% [markdown]
# <a href="https://colab.research.google.com/github/ARekikGT/The_IRIS_Project/blob/main/IRIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Performing Unsupervised Machine Learning on the 'Iris' dataset to predict the optimal number of clusters. Utilize either R or Python for the analysis and visually represent the identified clusters.

# %% [markdown]
# # **Author: AHMED REKIK.**
# **DATA SCIENCE AND BUSINESS ANALYTICS INTERN @ THE SPARKS FOUNDATION**
# ### Dataset: (https://bit.ly/2kXTdox)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
iris = pd.read_csv("/content/IRIS.csv")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_0, *['sepal_length'], **{})
# chart
# import numpy as np
# ...

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
iris["species"].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: species, dtype: int64

# %% [markdown]
# # **Scatter plot (EDA)**

# %%
iris.plot(kind='scatter', x='sepal_length', y= 'sepal_width')
plt.show()

# %%
sns.set_style('whitegrid')
MF =sns.FacetGrid(iris, hue="species", height =4)
MF.map(plt.scatter,"sepal_length","sepal_width")
MF.add_legend()
plt.show()

# %% [markdown]
# ## **Pair Plot (EDA)**

# %%
sns.set_style("whitegrid")
sns.pairplot(iris, hue="species",height=3)
plt.show()

# %% [markdown]
# # **Histogram (EDA)**

# %%
iris_setosa = iris.loc[iris['species'] == 'Iris-setosa']
iris_virginica = iris.loc[iris['species']=='Iris-virginica']
iris_versicolor = iris.loc[iris['species']=='Iris-versicolor']

plt.plot(iris_setosa['petal_length'], np.zeros_like(iris_setosa['petal_length']),'o')
plt.plot(iris_virginica['petal_length'], np.zeros_like(iris_virginica['petal_length']),'o')
plt.plot(iris_versicolor['petal_length'], np.zeros_like(iris_versicolor['petal_length']),'o')
plt.show()

# %%
## Histogram
FM = sns.FacetGrid(iris,hue='species',height=5)
FM.map(sns.histplot,'petal_length')
FM.add_legend()
plt.show()

# %%
fm = sns.FacetGrid(iris,hue='species',height =5)
fm.map(sns.histplot,'petal_width')
fm.add_legend()
plt.show()

# %% [markdown]
# **Cumulative Distribution Function CDF**
#
# **check the probability **

# %%
counts, bin_edges = np.histogram(iris_setosa['petal_length'], bins=10, density=True)
pdf= counts/(sum(counts))
pdf
bin_edges

# compute CDF
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)
plt.xlabel("PetalLength")
plt.ylabel("Probability")
plt.show()

# %% [markdown]
# # **Mean and Standard Deviation**

# %%
print("Means:")
print(np.mean(iris_setosa['petal_length']))
#Mean with an outlier
print(np.mean(np.append(iris_setosa["petal_length"],50)))
print(np.mean(iris_virginica['petal_length']))
print(np.mean(iris_versicolor['petal_length']))

print("\nStd-dev:")
print(np.std(iris_setosa['petal_length']))
print(np.std(iris_virginica['petal_length']))
print(np.std(iris_versicolor['petal_length']))
# Out:
# Means:
# 1.464
# 2.4156862745098038
# 5.5520000000000005
# 4.26
#
# Std-dev:
# 0.17176728442867112
# 0.546347874526844
# 0.4651881339845203

# %% [markdown]
# # **box plot**

# %%
sns.boxplot(x='species',y='petal_length', data=iris)
plt.show()

# %% [markdown]
# # **violin plot**

# %%
sns.violinplot(x='species',y='petal_length',data=iris)
plt.show()
